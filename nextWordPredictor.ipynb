# %% [markdown]
# <a href="https://colab.research.google.com/github/divyuuu/nextWordPredictor/blob/main/nextWordPredictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = """Alex: Lets start with this: AI is a revolutionary tool thats transforming industries. From healthcare to education, AI has improved efficiency, accuracy, and productivity. For instance, AI-powered diagnostic tools can detect diseases like cancer earlier than traditional methods. Isn’t that incredible?

Jamie: Sure, but let’s not overlook the risks. AI is a double-edged sword. For every medical breakthrough, there’s a potential misuse, like deepfake technology being used to spread misinformation. And let’s not forget how AI is threatening millions of jobs by automating repetitive tasks.

Alex: I get your concern, but history shows that technological advancements often lead to job displacement initially, followed by the creation of new opportunities. Think of the Industrial Revolution—it replaced some jobs but created entirely new industries. AI is no different. It’s about adapting and upskilling the workforce.

Jamie: That sounds ideal, but it’s not that simple. The speed at which AI is advancing leaves little time for people to reskill. And what about the ethical concerns? Bias in AI systems can lead to unfair treatment in areas like hiring, lending, or even law enforcement. These systems are only as unbiased as the data they’re trained on, and often that data reflects societal prejudices.

Alex: You’re right about bias being a challenge, but it’s not insurmountable. Researchers are working on techniques to reduce bias in AI algorithms. Plus, the benefits still outweigh the risks. In education, AI-powered tools personalize learning for students, helping them learn at their own pace. This can bridge gaps in traditional education systems.

Jamie: Personalization is great, but at what cost? AI-driven systems can infringe on privacy. These tools collect massive amounts of data, and there’s always the risk of that data being misused or leaked. Moreover, the over-reliance on AI can lead to a loss of human touch in critical areas like education and healthcare.

Alex: Privacy is a valid concern, and regulations like GDPR aim to address these issues. With proper governance, we can minimize risks. As for the "human touch," AI isn’t replacing professionals; it’s augmenting their capabilities. In healthcare, for example, AI assists doctors, enabling them to make better decisions, not replace them.

Jamie: That’s the optimistic view, but let’s consider the existential risks. Renowned figures like Stephen Hawking and Elon Musk have warned about AI becoming uncontrollable. If AI surpasses human intelligence, it could act in ways we can’t predict or control. The risks of an AI arms race are also very real.

Alex: True, superintelligence poses theoretical risks, but we’re far from achieving that level of AI. The focus now should be on ensuring responsible AI development. Instead of fearing hypothetical scenarios, we should harness AI’s potential to solve pressing global challenges like climate change and food scarcity.

Jamie: Speaking of climate change, AI itself contributes to the problem. Training large AI models consumes immense computational resources, which in turn, require significant energy. This carbon footprint is something we can’t ignore if we’re talking about sustainability.

Alex: A fair point, but strides are being made in making AI more energy-efficient. Researchers are developing models that are both powerful and less resource-intensive. Also, AI can help combat climate change by optimizing energy consumption in industries and enabling smarter resource management.

Jamie: Even if we achieve energy efficiency, there’s still the issue of inequality. Only a few tech giants control the majority of AI advancements, creating a concentration of power. This exacerbates wealth disparities and makes developing nations dependent on these corporations.

Alex: Democratizing AI is indeed crucial, and open-source initiatives like TensorFlow and Hugging Face are steps in the right direction. With collaboration between governments, academia, and private companies, we can ensure AI benefits everyone, not just a select few.

Jamie: Collaboration is easier said than done. Geopolitical tensions often result in countries pursuing their own AI agendas, leading to fragmentation. Without a global framework, we risk uncoordinated development that could have unforeseen consequences.

Alex: That’s why international cooperation is essential, just like we’ve seen with nuclear treaties. Organizations like the UN and OECD are already discussing AI ethics and governance. It’s not perfect, but it’s a start.

Jamie: Governance is one part, but the social implications are another. AI might improve productivity, but it also risks dehumanizing society. If machines do everything, where do we draw the line for human engagement and creativity?

Alex: AI doesn’t eliminate creativity; it enhances it. Artists, musicians, and writers are already using AI as a tool to push creative boundaries. It’s about collaboration between humans and machines, not a replacement.

Jamie: That’s one perspective, but it still feels like we’re treading into uncertain waters. Until we fully understand and mitigate the risks, we should approach AI with caution.

Alex: Agreed, caution is necessary, but fear shouldn’t paralyze progress. AI is a powerful tool, and like any tool, its impact depends on how we use it. With the right safeguards, it can truly be a boon for humanity.
Alex: Jamie, let’s dive deeper into the creative aspect you mentioned. You worry about dehumanization, but I see AI fostering a new era of collaboration. For instance, AI can analyze centuries of art, literature, or music and generate ideas that inspire human creators. Wouldn’t that be an exciting way to amplify human ingenuity?

Jamie: It might sound exciting, but where do we draw the line between human and machine creativity? If AI starts producing art, music, or even literature indistinguishable from human-created work, doesn’t it dilute the value of human effort? More importantly, who owns that creation—the artist or the company that built the AI?

Alex: Good questions! Ownership is a complex topic, but current legal frameworks are evolving to address it. For example, some jurisdictions are already discussing how to assign copyright for AI-generated works. Plus, think of the opportunities: small creators or indie developers could use AI to bring their visions to life without needing massive resources.

Jamie: Sure, AI can empower individuals, but it can also stifle competition. Let’s say a few big companies monopolize advanced AI tools. Smaller creators might find themselves outcompeted, not empowered. And if algorithms start dictating what art or media gets promoted—based on data, not creativity—won’t it lead to homogenized content?

Alex: That’s a risk, but it’s not unique to AI. Any technology can be misused if left unchecked. Regulatory frameworks and public awareness can ensure that AI-driven platforms remain diverse and fair. Besides, AI doesn’t just automate creativity; it democratizes access to knowledge. A student in a rural area can now learn advanced topics using AI tutors.

Jamie: True, but let’s consider the psychological impact of AI tutors. While they’re effective, they lack emotional intelligence. A teacher does more than teach—they inspire, mentor, and connect on a human level. Can an AI really provide that? Aren’t we at risk of creating a generation overly dependent on machines?

Alex: That’s an interesting point, but AI isn’t meant to replace human teachers—it’s meant to assist them. AI tutors can handle repetitive tasks, like grading or providing practice exercises, freeing up teachers to focus on mentorship and emotional connections. It’s a partnership, not a replacement.

Jamie: Maybe in theory, but the reality is often different. Cash-strapped educational systems might rely on AI to cut costs, reducing the role of teachers. And speaking of costs, AI itself isn’t cheap. Implementing it in underserved areas is a challenge, which could widen the global education gap rather than closing it.

Alex: That’s a fair concern, but AI doesn’t have to be expensive. Open-source platforms and affordable devices are already making AI tools accessible in low-income regions. Plus, governments and NGOs can invest in scalable AI solutions for education. It’s about prioritizing equitable implementation.

Jamie: Implementation is key, but AI also raises questions about decision-making power. Take healthcare: should an AI system’s recommendation always take precedence over a doctor’s judgment? AI may process data faster, but it doesn’t understand context, empathy, or the nuances of a patient’s life.

Alex: Absolutely, AI should assist, not override human decisions. The ideal scenario is a collaborative approach where doctors use AI insights to make more informed choices. And let’s not forget the lives AI saves—like in rural areas where access to specialists is limited. AI-powered diagnostics can fill those gaps.

Jamie: But what about accountability? If an AI misdiagnoses a patient, who’s responsible? The developer? The hospital? The AI itself? Without clear accountability, we’re walking into a legal and ethical minefield.

Alex: True, accountability is a pressing issue. That’s why robust guidelines and testing are critical before deploying AI in sensitive fields. Companies need to ensure transparency in their algorithms, and governments must enforce strict oversight. These safeguards are evolving alongside the technology.

Jamie: Even with safeguards, AI’s potential for misuse remains alarming. Autonomous weapons, for instance, could lead to devastating consequences if deployed irresponsibly. And cyberattacks powered by AI could cripple infrastructure on an unprecedented scale.

Alex: Agreed, militarization of AI is a scary prospect. That’s why international treaties and ethical guidelines are crucial. Just as we have protocols for nuclear weapons, we need a global consensus on the use of AI in warfare. At the same time, let’s not overlook how AI strengthens cybersecurity by detecting and preventing threats faster than ever.

Jamie: While AI might bolster defenses, it also escalates the arms race. For every defensive AI, there’s an offensive counterpart. The balance of power is constantly shifting, and if rogue states or bad actors gain access to advanced AI, the consequences could be catastrophic.

Alex: That’s why collaboration and transparency are vital. Countries and tech leaders need to work together to ensure AI’s safe development. It’s not a perfect solution, but the alternative—stifling AI research—could leave us unprepared for challenges like pandemics or climate crises that AI could help address.

Jamie: You’re optimistic, Alex, but I still think we’re rushing into uncharted territory without fully understanding the consequences. AI might solve some problems, but it could also create new ones. Until we address these risks comprehensively, we need to be cautious.

Alex: Jamie, caution is necessary, but so is progress. AI has the potential to revolutionize our world for the better—if we approach it responsibly. It’s not about fearing AI; it’s about managing it wisely. Let’s work toward a future where AI truly serves humanity, not the other way around.
Alex: Let’s shift gears, Jamie. AI is not just about creativity or industry—it has immense potential in the political landscape. For example, governments can use AI to analyze public sentiment, predict trends, and make more informed policy decisions. Don’t you think that could lead to better governance?

Jamie: It sounds good on paper, but politics is already rife with manipulation, and AI could make it worse. Imagine AI-driven propaganda machines that spread misinformation faster than it can be debunked. Social media algorithms already polarize society; introducing more advanced AI could make the divide even deeper.

Alex: I see your point, but it doesn’t have to be that way. AI can also be used to counter misinformation. Fact-checking bots, for instance, can quickly identify and debunk fake news. Governments and organizations can use AI to foster transparency by providing real-time insights into their decisions and spending.

Jamie: That assumes governments will use AI ethically, which isn’t guaranteed. Authoritarian regimes could use AI for mass surveillance, suppressing dissent, and controlling their populations. Facial recognition technology is already being misused in some parts of the world to monitor citizens. Doesn’t that worry you?

Alex: Absolutely, misuse is a concern. But the solution is not to abandon AI—it’s to implement ethical guidelines and international regulations. Democratic countries can lead by example, using AI to enhance public welfare while maintaining checks and balances to prevent abuse.

Jamie: That’s easier said than done. Even democratic governments aren’t immune to using AI in questionable ways. Predictive policing, for instance, is already controversial. AI algorithms often disproportionately target marginalized communities because they reflect biases in the data they’re trained on. How can we trust governments to get this right?

Alex: You’re right—predictive policing is a contentious issue. But rather than scrapping the idea, we should work on creating unbiased systems and involving diverse stakeholders in their development. AI can help detect corruption, optimize public services, and even identify inefficiencies in governance if applied correctly.

Jamie: Optimizing services is great, but there’s also the issue of accountability. If an AI makes a policy recommendation that backfires, who takes responsibility? Politicians could use AI as a scapegoat, saying, "The algorithm made the decision, not us." That could erode trust in governance.

Alex: That’s a valid concern, but AI doesn’t have to replace human accountability. It should serve as an advisor, providing insights and recommendations while humans make the final call. Transparency in how AI is used can ensure that leaders remain accountable for their decisions.

Jamie: Transparency is crucial, but let’s talk about election processes. AI-powered tools can analyze voter behavior and target them with personalized political ads. While this can engage voters, it also opens the door to manipulation. We’ve already seen how data analytics influenced elections—what happens when AI takes it to the next level?

Alex: You’re referring to cases like Cambridge Analytica, right? Those events highlighted the need for stricter data privacy laws. AI doesn’t inherently manipulate voters; it’s the misuse of AI by political actors that’s the issue. Proper legislation can regulate how AI is used in political campaigns.

Jamie: Legislation helps, but enforcement is often lagging. By the time regulations catch up, the damage is done. Moreover, AI can amplify issues like gerrymandering, where districts are redrawn to favor certain political parties. An AI system could analyze voter demographics and make this process even more precise—and undemocratic.

Alex: That’s true, but AI can also be a force for democratization. For instance, it can enable more inclusive participation in politics. Virtual assistants can help citizens navigate complex policies, understand their rights, and even participate in digital town halls. It’s about using AI to engage, not exclude.

Jamie: That’s a hopeful vision, but we must be realistic. The political world is inherently competitive, and AI’s power will likely be exploited for political gain. Without global cooperation, the risks will outweigh the benefits. How do you ensure that AI doesn’t become just another tool for those in power to consolidate control?

Alex: Global cooperation is indeed the key. Just like we’ve come together to address issues like climate change, we need a united approach to AI governance. Bodies like the United Nations or World Economic Forum could create frameworks for ethical AI use in politics, ensuring it benefits citizens, not just leaders.

Jamie: That sounds idealistic, but geopolitics often gets in the way. Countries have different values, priorities, and levels of technological development. While some nations might embrace ethical AI, others could weaponize it to gain a strategic edge. How do we address that disparity?

Alex: By building alliances and sharing best practices. Democracies can form coalitions to set global standards, just as they’ve done with trade agreements or human rights conventions. Public pressure and advocacy can also push governments toward more responsible AI use.

Jamie: Coalitions are a start, but the road ahead is complex. AI has the potential to reshape politics for better or worse. Until we solve the ethical, social, and geopolitical challenges it brings, I believe we should approach its use in politics with extreme caution.

Alex: I agree that caution is necessary, but let’s not lose sight of AI’s potential to transform governance and empower citizens. With thoughtful regulation, collaboration, and innovation, AI could be a catalyst for a more equitable and efficient political system. The key lies in using it wisely.
Alex: You know, Jamie, I think love in the AI era is becoming more complicated than ever. People are using dating apps that leverage AI algorithms to match them with "the perfect partner." It sounds efficient, but doesn’t it take away the charm of old-school romance?

Jamie: Honestly, Alex, I don’t see the harm in it. These apps don’t take away romance—they just make meeting people easier. How is that different from mutual friends introducing you to someone? If anything, AI helps cut through the noise and connect people with shared interests or values.

Alex: Maybe, but there’s something magical about meeting someone organically, like at a coffee shop or a random event. With AI-curated matches, it feels so transactional. Like, are we choosing love based on algorithms rather than chemistry? That can’t be healthy.

Jamie: Come on, Alex. Chemistry isn’t just about a first meeting. It develops over time. And let’s face it—not everyone has the luxury of stumbling upon their soulmate in a coffee shop. AI is leveling the playing field for people who might otherwise struggle to find connections in today’s fast-paced world.

Alex: Sure, it’s convenient, but isn’t it also superficial? AI focuses on things like hobbies, physical preferences, or swipe behaviors. Can a machine really predict something as complex as love? It feels like we’re reducing relationships to data points.

Jamie: That’s where you’re wrong. These algorithms are based on psychology and behavior patterns. They don’t guarantee love, but they give you a starting point. Besides, even old-school relationships start with surface-level impressions. It’s what happens after that counts.

Alex: Fair enough, but what about the downside? AI-driven dating apps encourage people to keep swiping endlessly, thinking there’s always a better option out there. It’s creating a "grass is greener" mentality, making it harder for people to commit.

Jamie: That’s more about the user’s mindset than the technology itself. If someone’s commitment-phobic, they’ll find a way to avoid settling down—with or without AI. At least these platforms give people more options, especially for those who feel isolated or marginalized in traditional dating settings.

Alex: You might have a point there, but let’s not ignore the darker side of AI in relationships. Have you heard about AI-powered virtual companions? People are actually forming emotional bonds with chatbots. Isn’t that unsettling? How can we expect real human connections when some people are turning to AI for companionship?

Jamie: I don’t think it’s as dystopian as you’re making it out to be. For some people—like those dealing with social anxiety or loneliness—AI companions can be a stepping stone to building confidence. It’s not a replacement for real relationships; it’s a temporary support system.

Alex: But what if people start preferring AI companions over real relationships? AI doesn’t argue, doesn’t demand, and is always available. That’s not a stepping stone; that’s escapism. It could make people even more detached from genuine human connections.

Jamie: I see your concern, but I think humans crave authenticity at their core. AI might offer comfort, but it can’t replicate the depth and unpredictability of real relationships. People will always value that, no matter how advanced AI becomes.

Alex: Maybe you’re right. I just feel like love should be messy and imperfect. It’s in the misunderstandings, compromises, and spontaneous moments that relationships grow. AI might make things too… streamlined. Where’s the romance in that?

Jamie: Romance isn’t about how you meet; it’s about what you build together. Whether it starts through an algorithm or a chance encounter, the effort and emotion you put into it are what make it meaningful. AI is just a tool—it’s up to us to use it wisely.

Alex: I guess we’re back to the same conclusion we had about politics and creativity—AI is a tool, not a replacement. But I still think love is one area where we should be careful about letting machines play too big a role.

Jamie: Agreed. Whether it’s love, politics, or creativity, it all boils down to balance. As long as we don’t let technology overshadow the human element, we’ll be fine. So, are you going to swipe right on someone tonight, or should we leave it to fate?

Alex: Ha! Maybe I’ll give both a try—balance, right?"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([data])

# %%
len(tokenizer.word_index)
# Out:
# 1122

# %%
input_sequences = []
for sentence in data.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
 input_sequences
# Out:
# [[10, 415],
#  [10, 415, 78],
#  [10, 415, 78, 26],
#  [10, 415, 78, 26, 64],
#  [10, 415, 78, 26, 64, 1],
#  [10, 415, 78, 26, 64, 1, 7],
#  [10, 415, 78, 26, 64, 1, 7, 5],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79, 417],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79, 417, 418],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79, 417, 418, 163],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79, 417, 418, 163, 98],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79, 417, 418, 163, 98, 123],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79, 417, 418, 163, 98, 123, 3],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79, 417, 418, 163, 98, 123, 3, 80],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79, 417, 418, 163, 98, 123, 3, 80, 1],
#  [10, 415, 78, 26, 64, 1, 7, 5, 416, 79, 417, 418, 163, 98, 123, 3, 80, 1, 99],
#  [10,
#   415,
#   78,
#   26,
#   64,
#   1,
#   7,
#   5,
#   416,
#   79,
#   417,
#   418,
#   163,
#   98,
#   123,
#   3,
#   80,
# ...

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding = 'pre')

# %%
X = padded_input_sequences[:,:-1]
#This is the padded inputs until size 'n-1'

# %%
Y = padded_input_sequences[:,-1]
#This is the padded outputs that is the last element

# %%
X.shape
# Out:
# (3258, 65)

# %%
Y.shape
# Out:
# (3258,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(Y,num_classes = 1123)

# %%
y.shape
# Out:
# (3258, 1123)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Input

# %%
model = Sequential()
model.add(Input(shape=(65,)))  # Specify input length here
model.add(Embedding(1123, 100))
model.add(LSTM(150))
model.add(Dense(1123, activation='softmax'))

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)              │ (None, 65, 100)             │         112,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 150)                 │         150,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1123)                │         169,573 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 432,473 (1.65 MB)
#  Trainable params: 432,473 (1.65 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y, epochs = 100)
# Out:
# Epoch 1/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 18s 137ms/step - accuracy: 0.0316 - loss: 6.7355
# Epoch 2/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 14s 137ms/step - accuracy: 0.0342 - loss: 6.1297
# Epoch 3/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 21s 140ms/step - accuracy: 0.0329 - loss: 6.0283
# Epoch 4/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 20s 135ms/step - accuracy: 0.0454 - loss: 5.8611
# Epoch 5/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 21s 139ms/step - accuracy: 0.0429 - loss: 5.6859
# Epoch 6/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 0.0437 - loss: 5.5440
# Epoch 7/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 151ms/step - accuracy: 0.0642 - loss: 5.3743
# Epoch 8/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 20s 146ms/step - accuracy: 0.0689 - loss: 5.2336
# Epoch 9/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.0750 - loss: 4.9811
# Epoch 10/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 19s 141ms/step - accuracy: 0.0846 - loss: 4.7992
# Epoch 11/100
# ...

# %%
import time
import numpy as np
text = "i thought about you and"
for i in range(10):
  token_text  = tokenizer.texts_to_sequences([text])[0]
  padded_token_text = pad_sequences([token_text], maxlen= 65, padding = 'pre')
  pos = np.argmax(model.predict(padded_token_text))
  for word, index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# i thought about you and concern
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# i thought about you and concern but
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# i thought about you and concern but ai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# i thought about you and concern but ai doesn’t
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# i thought about you and concern but ai doesn’t have
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# i thought about you and concern but ai doesn’t have to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# i thought about you and concern but ai doesn’t have to be
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# i thought about you and concern but ai doesn’t have to be expensive
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# i thought about you and concern but ai doesn’t have to be expensive open
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# i thought about you and concern but ai doesn’t have to be expensive open source
